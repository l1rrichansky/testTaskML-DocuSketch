# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


def draw_plots():
    df = pd.read_json('deviation.json')
    s = []
    check = []
    for i in df:
        for j in df:
            if i != 'name' and j != 'name' and i != j and {i, j} not in check:  # actually you can check the type of a column but i used 'name' exception
                plt.scatter(df[i], df[j])
                plt.xlabel(i)
                plt.ylabel(j)
                plt.savefig(f"plots/{i}-{j}.png")
                #plt.show()
                s.append(f"plots/{i}-{j}.png")
                plt.clf()
                check.append({i, j})
    sns.pairplot(df)  # showing all pair diagrams
    return s


draw_plots()
# Out:
# ['plots/gt_corners-rb_corners.png',
#  'plots/gt_corners-mean.png',
#  'plots/gt_corners-max.png',
#  'plots/gt_corners-min.png',
#  'plots/gt_corners-floor_mean.png',
#  'plots/gt_corners-floor_max.png',
#  'plots/gt_corners-floor_min.png',
#  'plots/gt_corners-ceiling_mean.png',
#  'plots/gt_corners-ceiling_max.png',
#  'plots/gt_corners-ceiling_min.png',
#  'plots/rb_corners-mean.png',
#  'plots/rb_corners-max.png',
#  'plots/rb_corners-min.png',
#  'plots/rb_corners-floor_mean.png',
#  'plots/rb_corners-floor_max.png',
#  'plots/rb_corners-floor_min.png',
#  'plots/rb_corners-ceiling_mean.png',
#  'plots/rb_corners-ceiling_max.png',
#  'plots/rb_corners-ceiling_min.png',
#  'plots/mean-max.png',
#  'plots/mean-min.png',
#  'plots/mean-floor_mean.png',
#  'plots/mean-floor_max.png',
#  'plots/mean-floor_min.png',
#  'plots/mean-ceiling_mean.png',
#  'plots/mean-ceiling_max.png',
#  'plots/mean-ceiling_min.png',
#  'plots/max-min.png',
#  'plots/max-floor_mean.png',
#  'plots/max-floor_max.png',
#  'plots/max-floor_min.png',
#  'plots/max-ceiling_mean.png',
#  'plots/max-ceiling_max.png',
#  'plots/max-ceiling_min.png',
#  'plots/min-floor_mean.png',
#  'plots/min-floor_max.png',
#  'plots/min-floor_min.png',
#  'plots/min-ceiling_mean.png',
#  'plots/min-ceiling_max.png',
#  'plots/min-ceiling_min.png',
#  'plots/floor_mean-floor_max.png',
#  'plots/floor_mean-floor_min.png',
#  'plots/floor_mean-ceiling_mean.png',
#  'plots/floor_mean-ceiling_max.png',
#  'plots/floor_mean-ceiling_min.png',
#  'plots/floor_max-floor_min.png',
#  'plots/floor_max-ceiling_mean.png',
#  'plots/floor_max-ceiling_max.png',
#  'plots/floor_max-ceiling_min.png',
#  'plots/floor_min-ceiling_mean.png',
#  'plots/floor_min-ceiling_max.png',
#  'plots/floor_min-ceiling_min.png',
#  'plots/ceiling_mean-ceiling_max.png',
#  'plots/ceiling_mean-ceiling_min.png',
#  'plots/ceiling_max-ceiling_min.png']
